# %%
import pandas as pd
import matplotlib as plt

# %% [markdown]
# # First Dataset

# %%
# Convert CSV file to Pandas dataframe
df = pd.read_csv('helium-hotspot_2020-5-19_2021-9-5.csv')

# %%
# What does the data look like?
print(df)
# Out:
#             Date       Open       High        Low      Close        Volume  \
# 0    May-20-2020   0.254640   0.270376   0.232757   0.243026  7.284427e+04
# 1    May-21-2020   0.244108   0.253034   0.224571   0.224949  6.880030e+04
# 2    May-22-2020   0.227569   0.265449   0.224805   0.236512  6.818682e+04
# 3    May-23-2020   0.258715   0.265027   0.230073   0.261774  7.316549e+04
# 4    May-24-2020   0.256682   0.264516   0.224644   0.225019  6.977119e+04
# ..           ...        ...        ...        ...        ...           ...
# 469  Sep-01-2021  24.787900  24.787900  22.553600  23.287300  1.396656e+08
# 470  Sep-02-2021  23.327155  23.641600  22.648000  22.781000  6.391588e+07
# 471  Sep-03-2021  22.752600  23.755900  22.424800  22.924700  5.473708e+07
# 472  Sep-04-2021  22.934421  24.087800  22.870300  23.103800  5.178279e+07
# 473  Sep-05-2021  23.056800  24.062100  22.696700  23.726100  6.043301e+07
#
#      Market Cap
# 0             0
# 1             0
# ...

# %%
# What are the variables? Are there any missing values?
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 474 entries, 0 to 473
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        474 non-null    object
#  1   Open        474 non-null    float64
#  2   High        474 non-null    float64
#  3   Low         474 non-null    float64
#  4   Close       474 non-null    float64
#  5   Volume      474 non-null    float64
#  6   Market Cap  474 non-null    int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 26.0+ KB
# None

# %%
# What does the spread of the data look like?
df.describe()
# Out:
#              Open        High         Low       Close        Volume  \
# count  474.000000  474.000000  474.000000  474.000000  4.740000e+02
# mean     6.310426    6.777613    5.929031    6.358718  3.528505e+07
# std      6.791559    7.251172    6.400924    6.829374  5.514618e+07
# min      0.225517    0.238948    0.200066    0.224949  5.860977e+04
# 25%      1.196870    1.282754    1.132778    1.195768  7.787858e+05
# 50%      1.745306    1.904314    1.645296    1.752859  1.345824e+07
# 75%     12.747500   13.280000   11.912500   12.755000  4.507059e+07
# max     26.417200   26.495095   23.345847   26.122500  4.103494e+08
#
#          Market Cap
# count  4.740000e+02
# mean   1.342241e+08
# std    4.945561e+08
# min    0.000000e+00
# 25%    0.000000e+00
# 50%    0.000000e+00
# 75%    0.000000e+00
# max    2.371927e+09

# %%
df.plot(x='Date',y = ['Open','High','Low','Close'],figsize=(12, 6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.plot(x='Date',y = ['Volume','Market Cap'],figsize=(12, 6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# The first dataset has 474 days of data ranging from May 20, 2020 to September 5, 2021 which means that no days are missing. It has 7 variables: Date, Open, High, Low, Close, Volume, Market Cap. There are no missing values. At first glance, only the 'Market Cap' variable appears to have unreliable data (more than 75% of the values are 0). I will remove 'Market Cap' from the dataset. The 'Volume' variable may have a few outliers to explore.

# %%
# Remove Market Cap from dataframe
df = df.drop('Market Cap', axis = 1)

# %% [markdown]
# # Second Dataset

# %%
# Convert CSV file to Pandas dataframe
df2 = pd.read_csv('Nomics-CurrencyHistory-HELIUM-USD-1d-2021-09-06T20_54_38.248Z.csv')

# %%
# What does the data look like?
print(df2)
# Out:
#         close       high        low       open             timestamp  \
# 0   15.704877  17.363146  14.758251  16.173842  2021-05-30T00:00:00Z
# 1   16.233428  16.820951  15.075954  15.687716  2021-05-31T00:00:00Z
# 2   15.251917  16.688987  15.072103  16.205234  2021-06-01T00:00:00Z
# 3   15.590675  16.323396  14.758430  15.277674  2021-06-02T00:00:00Z
# 4   15.666258  16.163876  15.099949  15.588232  2021-06-03T00:00:00Z
# ..        ...        ...        ...        ...                   ...
# 95  22.688490  23.693307  22.365625  23.328856  2021-09-02T00:00:00Z
# 96  22.928118  23.821570  22.439001  22.712424  2021-09-03T00:00:00Z
# 97  23.071749  24.177696  22.846124  22.955703  2021-09-04T00:00:00Z
# 98  23.798570  24.274646  22.757922  23.073849  2021-09-05T00:00:00Z
# 99  24.041477  25.296368  23.106656  23.808559  2021-09-06T00:00:00Z
#
#          volume
# 0   60610141.26
# 1   45249410.54
# 2   33654396.08
# 3   47282771.02
# 4   40294385.55
# ..          ...
# ...

# %%
# What are the variables? Are there any missing values?
print(df2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   close      100 non-null    float64
#  1   high       100 non-null    float64
#  2   low        100 non-null    float64
#  3   open       100 non-null    float64
#  4   timestamp  100 non-null    object
#  5   volume     100 non-null    float64
# dtypes: float64(5), object(1)
# memory usage: 4.8+ KB
# None

# %%
# What does the spread of the data look like?
df2.describe()
# Out:
#             close        high         low        open        volume
# count  100.000000  100.000000  100.000000  100.000000  1.000000e+02
# mean    15.196513   16.085119   14.349722   15.119598  3.767003e+07
# std      4.346622    4.606389    3.988540    4.255575  2.727068e+07
# min      9.721219   10.175069    8.995651    9.715885  8.838700e+06
# 25%     12.400477   12.997512   11.851296   12.405092  2.230314e+07
# 50%     13.356485   14.066247   12.807394   13.364539  2.791658e+07
# 75%     16.682390   17.671781   15.951461   16.484254  4.535321e+07
# max     26.381693   26.738153   23.264042   26.413511  1.652531e+08

# %%
df2.plot(x='timestamp', y = ['close','high','low','open'],figsize=(12, 6))
# Out:
# <AxesSubplot:xlabel='timestamp'>

# %%
df2.plot(x='timestamp',y = ['volume'],figsize=(12, 6))
# Out:
# <AxesSubplot:xlabel='timestamp'>

# %% [markdown]
# The second dataset has data for 100 days ranging from May 20, 2020 to September 6, 2021. It has 6 variables: Timestamp, Open, High, Low, Close, Volume. There are no missing values. At first glance of the spread of the data, there are no extreme outliers to be concerned about.

# %% [markdown]
# # Comparing Datasets

# %% [markdown]
# I have two datasets of data on the price of HNT from different sources. I'm going to compare them to see if the values each provide for every day are reasonably similar. I will rearrange and rename the variables for the second dataset to match the first. I will only include days that both datasets contain: 99 days ranging from May 30, 2020 to September 5, 2021.

# %%
#Rearrange and Rename Columns to Match
df2 = df2[['timestamp','open','high','low','close','volume']]
df2 = df2.rename(columns={'timestamp':'Date','open':'Open','high':'High','low':'Low','close':'Close','volume':'Volume'})

# %%
# Drop Rows where Dates Don't Match
df = df.tail(99)
df2 = df2.head(99)

# %%
print(df)
# Out:
#             Date       Open     High        Low      Close        Volume
# 375  May-30-2021  16.150000  17.1700  14.676236  15.627154  1.609243e+08
# 376  May-31-2021  15.656371  16.4800  15.014054  16.150000  9.097793e+07
# 377  Jun-01-2021  16.230000  16.6400  15.110000  15.190000  5.578624e+07
# 378  Jun-02-2021  15.220000  16.2700  14.770000  15.720000  4.897535e+07
# 379  Jun-03-2021  15.630000  16.0400  15.100000  15.600000  5.886998e+07
# ..           ...        ...      ...        ...        ...           ...
# 469  Sep-01-2021  24.787900  24.7879  22.553600  23.287300  1.396656e+08
# 470  Sep-02-2021  23.327155  23.6416  22.648000  22.781000  6.391588e+07
# 471  Sep-03-2021  22.752600  23.7559  22.424800  22.924700  5.473708e+07
# 472  Sep-04-2021  22.934421  24.0878  22.870300  23.103800  5.178279e+07
# 473  Sep-05-2021  23.056800  24.0621  22.696700  23.726100  6.043301e+07
#
# [99 rows x 6 columns]

# %%
print(df2)
# Out:
#                     Date       Open       High        Low      Close  \
# 0   2021-05-30T00:00:00Z  16.173842  17.363146  14.758251  15.704877
# 1   2021-05-31T00:00:00Z  15.687716  16.820951  15.075954  16.233428
# 2   2021-06-01T00:00:00Z  16.205234  16.688987  15.072103  15.251917
# 3   2021-06-02T00:00:00Z  15.277674  16.323396  14.758430  15.590675
# 4   2021-06-03T00:00:00Z  15.588232  16.163876  15.099949  15.666258
# ..                   ...        ...        ...        ...        ...
# 94  2021-09-01T00:00:00Z  24.834657  25.163466  22.563724  23.310848
# 95  2021-09-02T00:00:00Z  23.328856  23.693307  22.365625  22.688490
# 96  2021-09-03T00:00:00Z  22.712424  23.821570  22.439001  22.928118
# 97  2021-09-04T00:00:00Z  22.955703  24.177696  22.846124  23.071749
# 98  2021-09-05T00:00:00Z  23.073849  24.274646  22.757922  23.798570
#
#          Volume
# 0   60610141.26
# 1   45249410.54
# 2   33654396.08
# 3   47282771.02
# 4   40294385.55
# ..          ...
# ...

# %%
# Compare Non-Date Variables
temp1 = df.reset_index(drop=True)
temp2 = df2.reset_index(drop=True)
temp1 = temp1.drop('Date', axis = 1)
temp2 = temp2.drop('Date', axis = 1)
compare = temp1.compare(temp2)

print(compare)
# Out:
#          Open                High                   Low                 Close  \
#          self      other     self      other       self      other       self
# 0   16.150000  16.173842  17.1700  17.363146  14.676236  14.758251  15.627154
# 1   15.656371  15.687716  16.4800  16.820951  15.014054  15.075954  16.150000
# 2   16.230000  16.205234  16.6400  16.688987  15.110000  15.072103  15.190000
# 3   15.220000  15.277674  16.2700  16.323396  14.770000  14.758430  15.720000
# 4   15.630000  15.588232  16.0400  16.163876  15.100000  15.099949  15.600000
# ..        ...        ...      ...        ...        ...        ...        ...
# 94  24.787900  24.834657  24.7879  25.163466  22.553600  22.563724  23.287300
# 95  23.327155  23.328856  23.6416  23.693307  22.648000  22.365625  22.781000
# 96  22.752600  22.712424  23.7559  23.821570  22.424800  22.439001  22.924700
# 97  22.934421  22.955703  24.0878  24.177696  22.870300  22.846124  23.103800
# ...

# %%
# Create DataFrame of % Differences Between Each Value in the Datasets
diff = pd.DataFrame()
for label in df.columns[1:]:
    diff[label] = abs((compare[label]['self']-compare[label]['other'])/compare[label]['self'])*100

diff.describe()
# Out:
#             Open       High        Low      Close     Volume
# count  99.000000  99.000000  99.000000  99.000000  99.000000
# mean    0.248370   0.884546   0.352040   0.402396  38.270030
# std     0.253045   0.711322   0.308836   0.444496  18.167704
# min     0.005057   0.009419   0.000336   0.014908   1.297762
# 25%     0.093922   0.333589   0.121577   0.112635  25.411200
# 50%     0.186716   0.676583   0.237256   0.267784  39.672590
# 75%     0.312353   1.206321   0.545206   0.528404  51.469928
# max     1.446246   3.020543   1.402031   2.915307  73.072467

# %% [markdown]
# These are the largest differences between the values for all days in the datasets:
# Diff in Opening Price of HNT: 1.4%
# Diff in Highest Price of HNT: 3.0%
# Diff in Lowest Price of HNT: 1.4%
# Diff in Closing Price of HNT: 2.9%
# Diff in Volume of HNT: 73.1%
#
# Besides 'Volume', the other variables show only small variation for each day between the datasets. This makes me feel confident that I can trust the accuracy of the data for 'Open', 'High', 'Low', and 'Close'. I do not feel confident about the accuracy of 'Volume' because, on average, the values are 40% different between the two databases. I will remove 'Volume' from the dataset.
#
# For training, validating, and testing purposes, I will use the full version of the first dataset even though I was only able to compare 99 of the data points to another source of data. I may use the second dataset as an additional pool of test data.

# %%
#A function that returns a DataFrame of the cleaned data
def cleanDF():

    df = pd.read_csv('helium-hotspot_2020-5-19_2021-9-5.csv')
    df = df.drop(['Market Cap','Volume'], axis = 1)

    return df
